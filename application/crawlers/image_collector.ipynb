# %% [markdown]
# # Download images organized in a csv

# %%
import pandas as pd
import os
import urllib.request

# %%
#Carregar o df 
df = pd.read_csv('data.csv')

df[['label','image_path']].tail()
# Out:
#         label                                         image_path
# 906  melanoma  http://atlasdermatologico.com.br/img?imageId=4299
# 907  melanoma  http://atlasdermatologico.com.br/img?imageId=4253
# 908  melanoma  http://atlasdermatologico.com.br/img?imageId=4245
# 909  melanoma  http://atlasdermatologico.com.br/img?imageId=4255
# 910  melanoma  http://atlasdermatologico.com.br/img?imageId=4304

# %%
#Criar uma diretorio para armazenar essas imagens 
data_dir = 'data/'

if os.path.exists(data_dir) == False:
    os.makedirs(data_dir)

#set os seus headers
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:109.0) Gecko/20100101 Firefox/116.0'}

#caminho para salvar a imagem
#print(img_dir)
def image_collector(file,label_column,image_column,headers, data_dir):
    labels = []
    img_name = []
    df = pd.read_csv(file)
    for i,_ in enumerate(df.values):
        try:
            url = df.loc[i,image_column]
            request = urllib.request.Request(url, headers=headers)
            img_dir = os.path.join(data_dir, os.path.basename(df.loc[i, image_column]))
            # Abre a URL e lê o conteúdo da resposta
            with urllib.request.urlopen(request) as response:
                image_data = response.read()
                with open(img_dir, 'wb') as img_file:
                    img_name.append(img_file.name[5:])# substring nome da imagem
                    labels.append(df.loc[1,'label'])
                    img_file.write(image_data)
            print("Imagem {} baixada com sucesso.".format(i))
        except urllib.error.HTTPError as e:
            print("Erro HTTP:", e)
        except urllib.error.URLError as e:
            print("Erro de URL:", e)
    
    d = {'labels': labels, 'img_name': img_name}
    df_data_labels = pd.DataFrame(data=d)
    pd.DataFrame.to_csv(df_data_labels,'data_labels.csv')
    return df_data_labels

# %%
image_collector('data.csv','label','image_path',headers, data_dir)
# Out:
# Imagem 0 baixada com sucesso.
# Imagem 1 baixada com sucesso.
# Imagem 2 baixada com sucesso.
# Imagem 3 baixada com sucesso.
# Imagem 4 baixada com sucesso.
# Imagem 5 baixada com sucesso.
# Imagem 6 baixada com sucesso.
# Imagem 7 baixada com sucesso.
# Imagem 8 baixada com sucesso.
# Imagem 9 baixada com sucesso.
# Imagem 10 baixada com sucesso.
# Imagem 11 baixada com sucesso.
# Imagem 12 baixada com sucesso.
# Imagem 13 baixada com sucesso.
# Imagem 14 baixada com sucesso.
# Imagem 15 baixada com sucesso.
# Imagem 16 baixada com sucesso.
# Imagem 17 baixada com sucesso.
# Imagem 18 baixada com sucesso.
# Imagem 19 baixada com sucesso.
# Imagem 20 baixada com sucesso.
# Imagem 21 baixada com sucesso.
# Imagem 22 baixada com sucesso.
# Imagem 23 baixada com sucesso.
# Imagem 24 baixada com sucesso.
# Imagem 25 baixada com sucesso.
# Imagem 26 baixada com sucesso.
# Imagem 27 baixada com sucesso.
# Imagem 28 baixada com sucesso.
# Imagem 29 baixada com sucesso.
# Imagem 30 baixada com sucesso.
# Imagem 31 baixada com sucesso.
# Imagem 32 baixada com sucesso.
# Imagem 33 baixada com sucesso.
# Imagem 34 baixada com sucesso.
# Imagem 35 baixada com sucesso.
# Imagem 36 baixada com sucesso.
# Imagem 37 baixada com sucesso.
# Imagem 38 baixada com sucesso.
# Imagem 39 baixada com sucesso.
# Imagem 40 baixada com sucesso.
# Imagem 41 baixada com sucesso.
# Imagem 42 baixada com sucesso.
# Imagem 43 baixada com sucesso.
# Imagem 44 baixada com sucesso.
# Imagem 45 baixada com sucesso.
# Imagem 46 baixada com sucesso.
# Imagem 47 baixada com sucesso.
# Imagem 48 baixada com sucesso.
# Imagem 49 baixada com sucesso.
# Imagem 50 baixada com sucesso.
# Imagem 51 baixada com sucesso.
# Imagem 52 baixada com sucesso.
# Imagem 53 baixada com sucesso.
# Imagem 54 baixada com sucesso.
# Imagem 55 baixada com sucesso.
# Imagem 56 baixada com sucesso.
# Imagem 57 baixada com sucesso.
# Imagem 58 baixada com sucesso.
# Imagem 59 baixada com sucesso.
# Imagem 60 baixada com sucesso.
# Imagem 61 baixada com sucesso.
# Imagem 62 baixada com sucesso.
# Imagem 63 baixada com sucesso.
# Imagem 64 baixada com sucesso.
# Imagem 65 baixada com sucesso.
# Imagem 66 baixada com sucesso.
# Imagem 67 baixada com sucesso.
# Imagem 68 baixada com sucesso.
# Imagem 69 baixada com sucesso.
# Imagem 70 baixada com sucesso.
# Imagem 71 baixada com sucesso.
# Imagem 72 baixada com sucesso.
# Imagem 73 baixada com sucesso.
# Imagem 74 baixada com sucesso.
# Imagem 75 baixada com sucesso.
# Imagem 76 baixada com sucesso.
# Imagem 77 baixada com sucesso.
# Imagem 78 baixada com sucesso.
# Imagem 79 baixada com sucesso.
# Imagem 80 baixada com sucesso.
# Imagem 81 baixada com sucesso.
# Imagem 82 baixada com sucesso.
# Imagem 83 baixada com sucesso.
# Imagem 84 baixada com sucesso.
# Imagem 85 baixada com sucesso.
# Imagem 86 baixada com sucesso.
# Imagem 87 baixada com sucesso.
# Imagem 88 baixada com sucesso.
# Imagem 89 baixada com sucesso.
# Imagem 90 baixada com sucesso.
# Imagem 91 baixada com sucesso.
# Imagem 92 baixada com sucesso.
# Imagem 93 baixada com sucesso.
# Imagem 94 baixada com sucesso.
# Imagem 95 baixada com sucesso.
# Imagem 96 baixada com sucesso.
# Imagem 97 baixada com sucesso.
# Imagem 98 baixada com sucesso.
# Imagem 99 baixada com sucesso.
# Imagem 100 baixada com sucesso.
# Imagem 101 baixada com sucesso.
# Imagem 102 baixada com sucesso.
# Imagem 103 baixada com sucesso.
# Imagem 104 baixada com sucesso.
# Imagem 105 baixada com sucesso.
# Imagem 106 baixada com sucesso.
# Imagem 107 baixada com sucesso.
# Imagem 108 baixada com sucesso.
# Imagem 109 baixada com sucesso.
# Imagem 110 baixada com sucesso.
# Imagem 111 baixada com sucesso.
# Imagem 112 baixada com sucesso.
# Imagem 113 baixada com sucesso.
# Imagem 114 baixada com sucesso.
# Imagem 115 baixada com sucesso.
# Imagem 116 baixada com sucesso.
# Imagem 117 baixada com sucesso.
# Imagem 118 baixada com sucesso.
# Imagem 119 baixada com sucesso.
# Imagem 120 baixada com sucesso.
# Imagem 121 baixada com sucesso.
# Imagem 122 baixada com sucesso.
# Imagem 123 baixada com sucesso.
# Imagem 124 baixada com sucesso.
# Imagem 125 baixada com sucesso.
# Imagem 126 baixada com sucesso.
# Imagem 127 baixada com sucesso.
# Imagem 128 baixada com sucesso.
# Imagem 129 baixada com sucesso.
# Imagem 130 baixada com sucesso.
# Imagem 131 baixada com sucesso.
# Imagem 132 baixada com sucesso.
# Imagem 133 baixada com sucesso.
# Imagem 134 baixada com sucesso.
# Imagem 135 baixada com sucesso.
# Imagem 136 baixada com sucesso.
# Imagem 137 baixada com sucesso.
# Imagem 138 baixada com sucesso.
# Imagem 139 baixada com sucesso.
# Imagem 140 baixada com sucesso.
# Imagem 141 baixada com sucesso.
# Imagem 142 baixada com sucesso.
# Imagem 143 baixada com sucesso.
# Imagem 144 baixada com sucesso.
# Imagem 145 baixada com sucesso.
# Imagem 146 baixada com sucesso.
# Imagem 147 baixada com sucesso.
# Imagem 148 baixada com sucesso.
# Imagem 149 baixada com sucesso.
# Imagem 150 baixada com sucesso.
# Imagem 151 baixada com sucesso.
# Imagem 152 baixada com sucesso.
# Imagem 153 baixada com sucesso.
# Imagem 154 baixada com sucesso.
# Imagem 155 baixada com sucesso.
# Imagem 156 baixada com sucesso.
# Imagem 157 baixada com sucesso.
# Imagem 158 baixada com sucesso.
# Imagem 159 baixada com sucesso.
# Imagem 160 baixada com sucesso.
# Imagem 161 baixada com sucesso.
# Imagem 162 baixada com sucesso.
# Imagem 163 baixada com sucesso.
# Imagem 164 baixada com sucesso.
# Imagem 165 baixada com sucesso.
# Imagem 166 baixada com sucesso.
# Imagem 167 baixada com sucesso.
# Imagem 168 baixada com sucesso.
# Imagem 169 baixada com sucesso.
# Imagem 170 baixada com sucesso.
# Imagem 171 baixada com sucesso.
# Imagem 172 baixada com sucesso.
# Imagem 173 baixada com sucesso.
# Imagem 174 baixada com sucesso.
# Imagem 175 baixada com sucesso.
# Imagem 176 baixada com sucesso.
# Imagem 177 baixada com sucesso.
# Imagem 178 baixada com sucesso.
# Imagem 179 baixada com sucesso.
# Imagem 180 baixada com sucesso.
# Imagem 181 baixada com sucesso.
# Imagem 182 baixada com sucesso.
# Imagem 183 baixada com sucesso.
# Imagem 184 baixada com sucesso.
# Imagem 185 baixada com sucesso.
# Imagem 186 baixada com sucesso.
# Imagem 187 baixada com sucesso.
# Imagem 188 baixada com sucesso.
# Imagem 189 baixada com sucesso.
# Imagem 190 baixada com sucesso.
# Imagem 191 baixada com sucesso.
# Imagem 192 baixada com sucesso.
# Imagem 193 baixada com sucesso.
# Imagem 194 baixada com sucesso.
# Imagem 195 baixada com sucesso.
# Imagem 196 baixada com sucesso.
# Imagem 197 baixada com sucesso.
# Imagem 198 baixada com sucesso.
# Imagem 199 baixada com sucesso.
# Imagem 200 baixada com sucesso.
# Imagem 201 baixada com sucesso.
# Imagem 202 baixada com sucesso.
# Imagem 203 baixada com sucesso.
# Imagem 204 baixada com sucesso.
# Imagem 205 baixada com sucesso.
# Imagem 206 baixada com sucesso.
# Imagem 207 baixada com sucesso.
# Imagem 208 baixada com sucesso.
# Imagem 209 baixada com sucesso.
# Imagem 210 baixada com sucesso.
# Imagem 211 baixada com sucesso.
# Imagem 212 baixada com sucesso.
# Imagem 213 baixada com sucesso.
# Imagem 214 baixada com sucesso.
# Imagem 215 baixada com sucesso.
# Imagem 216 baixada com sucesso.
# Imagem 217 baixada com sucesso.
# Imagem 218 baixada com sucesso.
# Imagem 219 baixada com sucesso.
# Imagem 220 baixada com sucesso.
# Imagem 221 baixada com sucesso.
# Imagem 222 baixada com sucesso.
# Imagem 223 baixada com sucesso.
# Imagem 224 baixada com sucesso.
# Imagem 225 baixada com sucesso.
# Imagem 226 baixada com sucesso.
# Imagem 227 baixada com sucesso.
# Imagem 228 baixada com sucesso.
# Imagem 229 baixada com sucesso.
# Imagem 230 baixada com sucesso.
# Imagem 231 baixada com sucesso.
# Imagem 232 baixada com sucesso.
# Imagem 233 baixada com sucesso.
# Imagem 234 baixada com sucesso.
# Imagem 235 baixada com sucesso.
# Imagem 236 baixada com sucesso.
# Imagem 237 baixada com sucesso.
# Imagem 238 baixada com sucesso.
# Imagem 239 baixada com sucesso.
# Imagem 240 baixada com sucesso.
# Imagem 241 baixada com sucesso.
# Imagem 242 baixada com sucesso.
# Imagem 243 baixada com sucesso.
# Imagem 244 baixada com sucesso.
# Imagem 245 baixada com sucesso.
# Imagem 246 baixada com sucesso.
# Imagem 247 baixada com sucesso.
# Imagem 248 baixada com sucesso.
# Imagem 249 baixada com sucesso.
# Imagem 250 baixada com sucesso.
# Imagem 251 baixada com sucesso.
# Imagem 252 baixada com sucesso.
# Imagem 253 baixada com sucesso.
# Imagem 254 baixada com sucesso.
# Imagem 255 baixada com sucesso.
# Imagem 256 baixada com sucesso.
# Imagem 257 baixada com sucesso.
# Imagem 258 baixada com sucesso.
# Imagem 259 baixada com sucesso.
# Imagem 260 baixada com sucesso.
# Imagem 261 baixada com sucesso.
# Imagem 262 baixada com sucesso.
# Imagem 263 baixada com sucesso.
# Imagem 264 baixada com sucesso.
# Imagem 265 baixada com sucesso.
# Imagem 266 baixada com sucesso.
# Imagem 267 baixada com sucesso.
# Imagem 268 baixada com sucesso.
# Imagem 269 baixada com sucesso.
# Imagem 270 baixada com sucesso.
# Imagem 271 baixada com sucesso.
# Imagem 272 baixada com sucesso.
# Imagem 273 baixada com sucesso.
# Imagem 274 baixada com sucesso.
# Imagem 275 baixada com sucesso.
# Imagem 276 baixada com sucesso.
# Imagem 277 baixada com sucesso.
# Imagem 278 baixada com sucesso.
# Imagem 279 baixada com sucesso.
# Imagem 280 baixada com sucesso.
# Imagem 281 baixada com sucesso.
# Imagem 282 baixada com sucesso.
# Imagem 283 baixada com sucesso.
# Imagem 284 baixada com sucesso.
# Imagem 285 baixada com sucesso.
# Imagem 286 baixada com sucesso.
# Imagem 287 baixada com sucesso.
# Imagem 288 baixada com sucesso.
# Imagem 289 baixada com sucesso.
# Imagem 290 baixada com sucesso.
# Imagem 291 baixada com sucesso.
# Imagem 292 baixada com sucesso.
# Imagem 293 baixada com sucesso.
# Imagem 294 baixada com sucesso.
# Imagem 295 baixada com sucesso.
# Imagem 296 baixada com sucesso.
# Imagem 297 baixada com sucesso.
# Imagem 298 baixada com sucesso.
# Imagem 299 baixada com sucesso.
# Imagem 300 baixada com sucesso.
# Imagem 301 baixada com sucesso.
# Imagem 302 baixada com sucesso.
# Imagem 303 baixada com sucesso.
# Imagem 304 baixada com sucesso.
# Imagem 305 baixada com sucesso.
# Imagem 306 baixada com sucesso.
# Imagem 307 baixada com sucesso.
# Imagem 308 baixada com sucesso.
# Imagem 309 baixada com sucesso.
# Imagem 310 baixada com sucesso.
# Imagem 311 baixada com sucesso.
# Imagem 312 baixada com sucesso.
# Imagem 313 baixada com sucesso.
# Imagem 314 baixada com sucesso.
# Imagem 315 baixada com sucesso.
# Imagem 316 baixada com sucesso.
# Imagem 317 baixada com sucesso.
# Imagem 318 baixada com sucesso.
# Imagem 319 baixada com sucesso.
# Imagem 320 baixada com sucesso.
# Imagem 321 baixada com sucesso.
# Imagem 322 baixada com sucesso.
# Imagem 323 baixada com sucesso.
# Imagem 324 baixada com sucesso.
# Imagem 325 baixada com sucesso.
# Imagem 326 baixada com sucesso.
# Imagem 327 baixada com sucesso.
# Imagem 328 baixada com sucesso.
# Imagem 329 baixada com sucesso.
# Imagem 330 baixada com sucesso.
# Imagem 331 baixada com sucesso.
# Imagem 332 baixada com sucesso.
# Imagem 333 baixada com sucesso.
# Imagem 334 baixada com sucesso.
# Imagem 335 baixada com sucesso.
# Imagem 336 baixada com sucesso.
# Imagem 337 baixada com sucesso.
# Imagem 338 baixada com sucesso.
# Imagem 339 baixada com sucesso.
# Imagem 340 baixada com sucesso.
# Imagem 341 baixada com sucesso.
# Imagem 342 baixada com sucesso.
# Imagem 343 baixada com sucesso.
# Imagem 344 baixada com sucesso.
# Imagem 345 baixada com sucesso.
# Imagem 346 baixada com sucesso.
# Imagem 347 baixada com sucesso.
# Imagem 348 baixada com sucesso.
# Imagem 349 baixada com sucesso.
# Imagem 350 baixada com sucesso.
# Imagem 351 baixada com sucesso.
# Imagem 352 baixada com sucesso.
# Imagem 353 baixada com sucesso.
# Imagem 354 baixada com sucesso.
# Imagem 355 baixada com sucesso.
# Imagem 356 baixada com sucesso.
# Imagem 357 baixada com sucesso.
# Imagem 358 baixada com sucesso.
# Imagem 359 baixada com sucesso.
# Imagem 360 baixada com sucesso.
# Imagem 361 baixada com sucesso.
# Imagem 362 baixada com sucesso.
# Imagem 363 baixada com sucesso.
# Imagem 364 baixada com sucesso.
# Imagem 365 baixada com sucesso.
# Imagem 366 baixada com sucesso.
# Imagem 367 baixada com sucesso.
# Imagem 368 baixada com sucesso.
# Imagem 369 baixada com sucesso.
# Imagem 370 baixada com sucesso.
# Imagem 371 baixada com sucesso.
# Imagem 372 baixada com sucesso.
# Imagem 373 baixada com sucesso.
# Imagem 374 baixada com sucesso.
# Imagem 375 baixada com sucesso.
# Imagem 376 baixada com sucesso.
# Imagem 377 baixada com sucesso.
# Imagem 378 baixada com sucesso.
# Imagem 379 baixada com sucesso.
# Imagem 380 baixada com sucesso.
# Imagem 381 baixada com sucesso.
# Imagem 382 baixada com sucesso.
# Imagem 383 baixada com sucesso.
# Imagem 384 baixada com sucesso.
# Imagem 385 baixada com sucesso.
# Imagem 386 baixada com sucesso.
# Imagem 387 baixada com sucesso.
# Imagem 388 baixada com sucesso.
# Imagem 389 baixada com sucesso.
# Imagem 390 baixada com sucesso.
# Imagem 391 baixada com sucesso.
# Imagem 392 baixada com sucesso.
# Imagem 393 baixada com sucesso.
# Imagem 394 baixada com sucesso.
# Imagem 395 baixada com sucesso.
# Imagem 396 baixada com sucesso.
# Imagem 397 baixada com sucesso.
# Imagem 398 baixada com sucesso.
# Imagem 399 baixada com sucesso.
# Imagem 400 baixada com sucesso.
# Imagem 401 baixada com sucesso.
# Imagem 402 baixada com sucesso.
# Imagem 403 baixada com sucesso.
# Imagem 404 baixada com sucesso.
# Imagem 405 baixada com sucesso.
# Imagem 406 baixada com sucesso.
# Imagem 407 baixada com sucesso.
# Imagem 408 baixada com sucesso.
# Imagem 409 baixada com sucesso.
# Imagem 410 baixada com sucesso.
# Imagem 411 baixada com sucesso.
# Imagem 412 baixada com sucesso.
# Imagem 413 baixada com sucesso.
# Imagem 414 baixada com sucesso.
# Imagem 415 baixada com sucesso.
# Imagem 416 baixada com sucesso.
# Imagem 417 baixada com sucesso.
# Imagem 418 baixada com sucesso.
# Imagem 419 baixada com sucesso.
# Imagem 420 baixada com sucesso.
# Imagem 421 baixada com sucesso.
# Imagem 422 baixada com sucesso.
# Imagem 423 baixada com sucesso.
# Imagem 424 baixada com sucesso.
# Imagem 425 baixada com sucesso.
# Imagem 426 baixada com sucesso.
# Imagem 427 baixada com sucesso.
# Imagem 428 baixada com sucesso.
# Imagem 429 baixada com sucesso.
# Imagem 430 baixada com sucesso.
# Imagem 431 baixada com sucesso.
# Imagem 432 baixada com sucesso.
# Imagem 433 baixada com sucesso.
# Imagem 434 baixada com sucesso.
# Imagem 435 baixada com sucesso.
# Imagem 436 baixada com sucesso.
# Imagem 437 baixada com sucesso.
# Imagem 438 baixada com sucesso.
# Imagem 439 baixada com sucesso.
# Imagem 440 baixada com sucesso.
# Imagem 441 baixada com sucesso.
# Imagem 442 baixada com sucesso.
# Imagem 443 baixada com sucesso.
# Imagem 444 baixada com sucesso.
# Imagem 445 baixada com sucesso.
# Imagem 446 baixada com sucesso.
# Imagem 447 baixada com sucesso.
# Imagem 448 baixada com sucesso.
# Imagem 449 baixada com sucesso.
# Imagem 450 baixada com sucesso.
# Imagem 451 baixada com sucesso.
# Imagem 452 baixada com sucesso.
# Imagem 453 baixada com sucesso.
# Imagem 454 baixada com sucesso.
# Imagem 455 baixada com sucesso.
# Imagem 456 baixada com sucesso.
# Imagem 457 baixada com sucesso.
# Imagem 458 baixada com sucesso.
# Imagem 459 baixada com sucesso.
# Imagem 460 baixada com sucesso.
# Imagem 461 baixada com sucesso.
# Imagem 462 baixada com sucesso.
# Imagem 463 baixada com sucesso.
# Imagem 464 baixada com sucesso.
# Imagem 465 baixada com sucesso.
# Imagem 466 baixada com sucesso.
# Imagem 467 baixada com sucesso.
# Imagem 468 baixada com sucesso.
# Imagem 469 baixada com sucesso.
# Imagem 470 baixada com sucesso.
# Imagem 471 baixada com sucesso.
# Imagem 472 baixada com sucesso.
# Imagem 473 baixada com sucesso.
# Imagem 474 baixada com sucesso.
# Imagem 475 baixada com sucesso.
# Imagem 476 baixada com sucesso.
# Imagem 477 baixada com sucesso.
# Imagem 478 baixada com sucesso.
# Imagem 479 baixada com sucesso.
# Imagem 480 baixada com sucesso.
# Imagem 481 baixada com sucesso.
# Imagem 482 baixada com sucesso.
# Imagem 483 baixada com sucesso.
# Imagem 484 baixada com sucesso.
# Imagem 485 baixada com sucesso.
# Imagem 486 baixada com sucesso.
# Imagem 487 baixada com sucesso.
# Imagem 488 baixada com sucesso.
# Imagem 489 baixada com sucesso.
# Imagem 490 baixada com sucesso.
# Imagem 491 baixada com sucesso.
# Imagem 492 baixada com sucesso.
# Imagem 493 baixada com sucesso.
# Imagem 494 baixada com sucesso.
# Imagem 495 baixada com sucesso.
# Imagem 496 baixada com sucesso.
# Imagem 497 baixada com sucesso.
# Imagem 498 baixada com sucesso.
# Imagem 499 baixada com sucesso.
# Imagem 500 baixada com sucesso.
# Imagem 501 baixada com sucesso.
# Imagem 502 baixada com sucesso.
# Imagem 503 baixada com sucesso.
# Imagem 504 baixada com sucesso.
# Imagem 505 baixada com sucesso.
# Imagem 506 baixada com sucesso.
# Imagem 507 baixada com sucesso.
# Imagem 508 baixada com sucesso.
# Imagem 509 baixada com sucesso.
# Imagem 510 baixada com sucesso.
# Imagem 511 baixada com sucesso.
# Imagem 512 baixada com sucesso.
# Imagem 513 baixada com sucesso.
# Imagem 514 baixada com sucesso.
# Imagem 515 baixada com sucesso.
# Imagem 516 baixada com sucesso.
# Imagem 517 baixada com sucesso.
# Imagem 518 baixada com sucesso.
# Imagem 519 baixada com sucesso.
# Imagem 520 baixada com sucesso.
# Imagem 521 baixada com sucesso.
# Imagem 522 baixada com sucesso.
# Imagem 523 baixada com sucesso.
# Imagem 524 baixada com sucesso.
# Imagem 525 baixada com sucesso.
# Imagem 526 baixada com sucesso.
# Imagem 527 baixada com sucesso.
# Imagem 528 baixada com sucesso.
# Imagem 529 baixada com sucesso.
# Imagem 530 baixada com sucesso.
# Imagem 531 baixada com sucesso.
# Imagem 532 baixada com sucesso.
# Imagem 533 baixada com sucesso.
# Imagem 534 baixada com sucesso.
# Imagem 535 baixada com sucesso.
# Imagem 536 baixada com sucesso.
# Imagem 537 baixada com sucesso.
# Imagem 538 baixada com sucesso.
# Imagem 539 baixada com sucesso.
# Imagem 540 baixada com sucesso.
# Imagem 541 baixada com sucesso.
# Imagem 542 baixada com sucesso.
# Imagem 543 baixada com sucesso.
# Imagem 544 baixada com sucesso.
# Imagem 545 baixada com sucesso.
# Imagem 546 baixada com sucesso.
# Imagem 547 baixada com sucesso.
# Imagem 548 baixada com sucesso.
# Imagem 549 baixada com sucesso.
# Imagem 550 baixada com sucesso.
# Imagem 551 baixada com sucesso.
# Imagem 552 baixada com sucesso.
# Imagem 553 baixada com sucesso.
# Imagem 554 baixada com sucesso.
# Imagem 555 baixada com sucesso.
# Imagem 556 baixada com sucesso.
# Imagem 557 baixada com sucesso.
# Imagem 558 baixada com sucesso.
# Imagem 559 baixada com sucesso.
# Imagem 560 baixada com sucesso.
# Imagem 561 baixada com sucesso.
# Imagem 562 baixada com sucesso.
# Imagem 563 baixada com sucesso.
# Imagem 564 baixada com sucesso.
# Imagem 565 baixada com sucesso.
# Imagem 566 baixada com sucesso.
# Imagem 567 baixada com sucesso.
# Imagem 568 baixada com sucesso.
# Imagem 569 baixada com sucesso.
# Imagem 570 baixada com sucesso.
# Imagem 571 baixada com sucesso.
# Imagem 572 baixada com sucesso.
# Imagem 573 baixada com sucesso.
# Imagem 574 baixada com sucesso.
# Imagem 575 baixada com sucesso.
# Imagem 576 baixada com sucesso.
# Imagem 577 baixada com sucesso.
# Imagem 578 baixada com sucesso.
# Imagem 579 baixada com sucesso.
# Imagem 580 baixada com sucesso.
# Imagem 581 baixada com sucesso.
# Imagem 582 baixada com sucesso.
# Imagem 583 baixada com sucesso.
# Imagem 584 baixada com sucesso.
# Imagem 585 baixada com sucesso.
# Imagem 586 baixada com sucesso.
# Imagem 587 baixada com sucesso.
# Imagem 588 baixada com sucesso.
# Imagem 589 baixada com sucesso.
# Imagem 590 baixada com sucesso.
# Imagem 591 baixada com sucesso.
# Imagem 592 baixada com sucesso.
# Imagem 593 baixada com sucesso.
# Imagem 594 baixada com sucesso.
# Imagem 595 baixada com sucesso.
# Imagem 596 baixada com sucesso.
# Imagem 597 baixada com sucesso.
# Imagem 598 baixada com sucesso.
# Imagem 599 baixada com sucesso.
# Imagem 600 baixada com sucesso.
# Imagem 601 baixada com sucesso.
# Imagem 602 baixada com sucesso.
# Imagem 603 baixada com sucesso.
# Imagem 604 baixada com sucesso.
# Imagem 605 baixada com sucesso.
# Imagem 606 baixada com sucesso.
# Imagem 607 baixada com sucesso.
# Imagem 608 baixada com sucesso.
# Imagem 609 baixada com sucesso.
# Imagem 610 baixada com sucesso.
# Imagem 611 baixada com sucesso.
# Imagem 612 baixada com sucesso.
# Imagem 613 baixada com sucesso.
# Imagem 614 baixada com sucesso.
# Imagem 615 baixada com sucesso.
# Imagem 616 baixada com sucesso.
# Imagem 617 baixada com sucesso.
# Imagem 618 baixada com sucesso.
# Imagem 619 baixada com sucesso.
# Imagem 620 baixada com sucesso.
# Imagem 621 baixada com sucesso.
# Imagem 622 baixada com sucesso.
# Imagem 623 baixada com sucesso.
# Imagem 624 baixada com sucesso.
# Imagem 625 baixada com sucesso.
# Imagem 626 baixada com sucesso.
# Imagem 627 baixada com sucesso.
# Imagem 628 baixada com sucesso.
# Imagem 629 baixada com sucesso.
# Imagem 630 baixada com sucesso.
# Imagem 631 baixada com sucesso.
# Imagem 632 baixada com sucesso.
# Imagem 633 baixada com sucesso.
# Imagem 634 baixada com sucesso.
# Imagem 635 baixada com sucesso.
# Imagem 636 baixada com sucesso.
# Imagem 637 baixada com sucesso.
# Imagem 638 baixada com sucesso.
# Imagem 639 baixada com sucesso.
# Imagem 640 baixada com sucesso.
# Imagem 641 baixada com sucesso.
# Imagem 642 baixada com sucesso.
# Imagem 643 baixada com sucesso.
# Imagem 644 baixada com sucesso.
# Imagem 645 baixada com sucesso.
# Imagem 646 baixada com sucesso.
# Imagem 647 baixada com sucesso.
# Imagem 648 baixada com sucesso.
# Imagem 649 baixada com sucesso.
# Imagem 650 baixada com sucesso.
# Imagem 651 baixada com sucesso.
# Imagem 652 baixada com sucesso.
# Imagem 653 baixada com sucesso.
# Imagem 654 baixada com sucesso.
# Imagem 655 baixada com sucesso.
# Imagem 656 baixada com sucesso.
# Imagem 657 baixada com sucesso.
# Imagem 658 baixada com sucesso.
# Imagem 659 baixada com sucesso.
# Imagem 660 baixada com sucesso.
# Imagem 661 baixada com sucesso.
# Imagem 662 baixada com sucesso.
# Imagem 663 baixada com sucesso.
# Imagem 664 baixada com sucesso.
# Imagem 665 baixada com sucesso.
# Imagem 666 baixada com sucesso.
# Imagem 667 baixada com sucesso.
# Imagem 668 baixada com sucesso.
# Imagem 669 baixada com sucesso.
# Imagem 670 baixada com sucesso.
# Imagem 671 baixada com sucesso.
# Imagem 672 baixada com sucesso.
# Imagem 673 baixada com sucesso.
# Imagem 674 baixada com sucesso.
# Imagem 675 baixada com sucesso.
# Imagem 676 baixada com sucesso.
# Imagem 677 baixada com sucesso.
# Imagem 678 baixada com sucesso.
# Imagem 679 baixada com sucesso.
# Imagem 680 baixada com sucesso.
# Imagem 681 baixada com sucesso.
# Imagem 682 baixada com sucesso.
# Imagem 683 baixada com sucesso.
# Imagem 684 baixada com sucesso.
# Imagem 685 baixada com sucesso.
# Imagem 686 baixada com sucesso.
# Imagem 687 baixada com sucesso.
# Imagem 688 baixada com sucesso.
# Imagem 689 baixada com sucesso.
# Imagem 690 baixada com sucesso.
# Imagem 691 baixada com sucesso.
# Imagem 692 baixada com sucesso.
# Imagem 693 baixada com sucesso.
# Imagem 694 baixada com sucesso.
# Imagem 695 baixada com sucesso.
# Imagem 696 baixada com sucesso.
# Imagem 697 baixada com sucesso.
# Imagem 698 baixada com sucesso.
# Imagem 699 baixada com sucesso.
# Imagem 700 baixada com sucesso.
# Imagem 701 baixada com sucesso.
# Imagem 702 baixada com sucesso.
# Imagem 703 baixada com sucesso.
# Imagem 704 baixada com sucesso.
# Imagem 705 baixada com sucesso.
# Imagem 706 baixada com sucesso.
# Imagem 707 baixada com sucesso.
# Imagem 708 baixada com sucesso.
# Imagem 709 baixada com sucesso.
# Imagem 710 baixada com sucesso.
# Imagem 711 baixada com sucesso.
# Imagem 712 baixada com sucesso.
# Imagem 713 baixada com sucesso.
# Imagem 714 baixada com sucesso.
# Imagem 715 baixada com sucesso.
# Imagem 716 baixada com sucesso.
# Imagem 717 baixada com sucesso.
# Imagem 718 baixada com sucesso.
# Imagem 719 baixada com sucesso.
# Imagem 720 baixada com sucesso.
# Imagem 721 baixada com sucesso.
# Imagem 722 baixada com sucesso.
# Imagem 723 baixada com sucesso.
# Imagem 724 baixada com sucesso.
# Imagem 725 baixada com sucesso.
# Imagem 726 baixada com sucesso.
# Imagem 727 baixada com sucesso.
# Imagem 728 baixada com sucesso.
# Imagem 729 baixada com sucesso.
# Imagem 730 baixada com sucesso.
# Imagem 731 baixada com sucesso.
# Imagem 732 baixada com sucesso.
# Imagem 733 baixada com sucesso.
# Imagem 734 baixada com sucesso.
# Imagem 735 baixada com sucesso.
# Imagem 736 baixada com sucesso.
# Imagem 737 baixada com sucesso.
# Imagem 738 baixada com sucesso.
# Imagem 739 baixada com sucesso.
# Imagem 740 baixada com sucesso.
# Imagem 741 baixada com sucesso.
# Imagem 742 baixada com sucesso.
# Imagem 743 baixada com sucesso.
# Imagem 744 baixada com sucesso.
# Imagem 745 baixada com sucesso.
# Imagem 746 baixada com sucesso.
# Imagem 747 baixada com sucesso.
# Imagem 748 baixada com sucesso.
# Imagem 749 baixada com sucesso.
# Imagem 750 baixada com sucesso.
# Imagem 751 baixada com sucesso.
# Imagem 752 baixada com sucesso.
# Imagem 753 baixada com sucesso.
# Imagem 754 baixada com sucesso.
# Imagem 755 baixada com sucesso.
# Imagem 756 baixada com sucesso.
# Imagem 757 baixada com sucesso.
# Imagem 758 baixada com sucesso.
# Imagem 759 baixada com sucesso.
# Imagem 760 baixada com sucesso.
# Imagem 761 baixada com sucesso.
# Imagem 762 baixada com sucesso.
# Imagem 763 baixada com sucesso.
# Imagem 764 baixada com sucesso.
# Imagem 765 baixada com sucesso.
# Imagem 766 baixada com sucesso.
# Imagem 767 baixada com sucesso.
# Imagem 768 baixada com sucesso.
# Imagem 769 baixada com sucesso.
# Imagem 770 baixada com sucesso.
# Imagem 771 baixada com sucesso.
# Imagem 772 baixada com sucesso.
# Imagem 773 baixada com sucesso.
# Imagem 774 baixada com sucesso.
# Imagem 775 baixada com sucesso.
# Imagem 776 baixada com sucesso.
# Imagem 777 baixada com sucesso.
# Imagem 778 baixada com sucesso.
# Imagem 779 baixada com sucesso.
# Imagem 780 baixada com sucesso.
# Imagem 781 baixada com sucesso.
# Imagem 782 baixada com sucesso.
# Imagem 783 baixada com sucesso.
# Imagem 784 baixada com sucesso.
# Imagem 785 baixada com sucesso.
# Imagem 786 baixada com sucesso.
# Imagem 787 baixada com sucesso.
# Imagem 788 baixada com sucesso.
# Imagem 789 baixada com sucesso.
# Imagem 790 baixada com sucesso.
# Imagem 791 baixada com sucesso.
# Imagem 792 baixada com sucesso.
# Imagem 793 baixada com sucesso.
# Imagem 794 baixada com sucesso.
# Imagem 795 baixada com sucesso.
# Imagem 796 baixada com sucesso.
# Imagem 797 baixada com sucesso.
# Imagem 798 baixada com sucesso.
# Imagem 799 baixada com sucesso.
# Imagem 800 baixada com sucesso.
# Imagem 801 baixada com sucesso.
# Imagem 802 baixada com sucesso.
# Imagem 803 baixada com sucesso.
# Imagem 804 baixada com sucesso.
# Imagem 805 baixada com sucesso.
# Imagem 806 baixada com sucesso.
# Imagem 807 baixada com sucesso.
# Imagem 808 baixada com sucesso.
# Imagem 809 baixada com sucesso.
# Imagem 810 baixada com sucesso.
# Imagem 811 baixada com sucesso.
# Imagem 812 baixada com sucesso.
# Imagem 813 baixada com sucesso.
# Imagem 814 baixada com sucesso.
# Imagem 815 baixada com sucesso.
# Imagem 816 baixada com sucesso.
# Imagem 817 baixada com sucesso.
# Imagem 818 baixada com sucesso.
# Imagem 819 baixada com sucesso.
# Imagem 820 baixada com sucesso.
# Imagem 821 baixada com sucesso.
# Imagem 822 baixada com sucesso.
# Imagem 823 baixada com sucesso.
# Imagem 824 baixada com sucesso.
# Imagem 825 baixada com sucesso.
# Imagem 826 baixada com sucesso.
# Imagem 827 baixada com sucesso.
# Imagem 828 baixada com sucesso.
# Imagem 829 baixada com sucesso.
# Imagem 830 baixada com sucesso.
# Imagem 831 baixada com sucesso.
# Imagem 832 baixada com sucesso.
# Imagem 833 baixada com sucesso.
# Imagem 834 baixada com sucesso.
# Imagem 835 baixada com sucesso.
# Imagem 836 baixada com sucesso.
# Imagem 837 baixada com sucesso.
# Imagem 838 baixada com sucesso.
# Imagem 839 baixada com sucesso.
# Imagem 840 baixada com sucesso.
# Imagem 841 baixada com sucesso.
# Imagem 842 baixada com sucesso.
# Imagem 843 baixada com sucesso.
# Imagem 844 baixada com sucesso.
# Imagem 845 baixada com sucesso.
# Imagem 846 baixada com sucesso.
# Imagem 847 baixada com sucesso.
# Imagem 848 baixada com sucesso.
# Imagem 849 baixada com sucesso.
# Imagem 850 baixada com sucesso.
# Imagem 851 baixada com sucesso.
# Imagem 852 baixada com sucesso.
# Imagem 853 baixada com sucesso.
# Imagem 854 baixada com sucesso.
# Imagem 855 baixada com sucesso.
# Imagem 856 baixada com sucesso.
# Imagem 857 baixada com sucesso.
# Imagem 858 baixada com sucesso.
# Imagem 859 baixada com sucesso.
# Imagem 860 baixada com sucesso.
# Imagem 861 baixada com sucesso.
# Imagem 862 baixada com sucesso.
# Imagem 863 baixada com sucesso.
# Imagem 864 baixada com sucesso.
# Imagem 865 baixada com sucesso.
# Imagem 866 baixada com sucesso.
# Imagem 867 baixada com sucesso.
# Imagem 868 baixada com sucesso.
# Imagem 869 baixada com sucesso.
# Imagem 870 baixada com sucesso.
# Imagem 871 baixada com sucesso.
# Imagem 872 baixada com sucesso.
# Imagem 873 baixada com sucesso.
# Imagem 874 baixada com sucesso.
# Imagem 875 baixada com sucesso.
# Imagem 876 baixada com sucesso.
# Imagem 877 baixada com sucesso.
# Imagem 878 baixada com sucesso.
# Imagem 879 baixada com sucesso.
# Imagem 880 baixada com sucesso.
# Imagem 881 baixada com sucesso.
# Imagem 882 baixada com sucesso.
# Imagem 883 baixada com sucesso.
# Imagem 884 baixada com sucesso.
# Imagem 885 baixada com sucesso.
# Imagem 886 baixada com sucesso.
# Imagem 887 baixada com sucesso.
# Imagem 888 baixada com sucesso.
# Imagem 889 baixada com sucesso.
# Imagem 890 baixada com sucesso.
# Imagem 891 baixada com sucesso.
# Imagem 892 baixada com sucesso.
# Imagem 893 baixada com sucesso.
# Imagem 894 baixada com sucesso.
# Imagem 895 baixada com sucesso.
# Imagem 896 baixada com sucesso.
# Imagem 897 baixada com sucesso.
# Imagem 898 baixada com sucesso.
# Imagem 899 baixada com sucesso.
# Imagem 900 baixada com sucesso.
# Imagem 901 baixada com sucesso.
# Imagem 902 baixada com sucesso.
# Imagem 903 baixada com sucesso.
# Imagem 904 baixada com sucesso.
# Imagem 905 baixada com sucesso.
# Imagem 906 baixada com sucesso.
# Imagem 907 baixada com sucesso.
# Imagem 908 baixada com sucesso.
# Imagem 909 baixada com sucesso.
# Imagem 910 baixada com sucesso.
#         labels                   img_name
# 0    psoriasis            psoriasis38.jpg
# 1    psoriasis      psoriasis-scalp20.jpg
# 2    psoriasis  psoriasis-congenital4.jpg
# 3    psoriasis   psoriasis-pustular54.jpg
# 4    psoriasis       psoriasis_nail84.jpg
# ..         ...                        ...
# 906  psoriasis           img?imageId=4299
# 907  psoriasis           img?imageId=4253
# 908  psoriasis           img?imageId=4245
# 909  psoriasis           img?imageId=4255
# 910  psoriasis           img?imageId=4304
#
# [911 rows x 2 columns]

# %%
pd.read_csv('data_labels.csv')
